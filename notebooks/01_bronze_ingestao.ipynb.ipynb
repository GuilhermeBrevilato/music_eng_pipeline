# %%
from pyspark.sql import SparkSession
from pyspark.sql import functions as F

from libs.schemas import (
    schema_users,
    schema_user_top_albums,
    schema_user_top_artists,
    schema_user_top_tracks,
)

from configs.paths import RAW, BRONZE, SILVER, GOLD

# %%
spark = (
    SparkSession.builder
        .appName("bronze_ingestion")
        .config("spark.sql.shuffle.partitions", "4")
        .config("spark.sql.adaptive.enabled", "true")
        .getOrCreate()
)

spark
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# 25/12/03 13:05:12 WARN Utils: Your hostname, MacBook-Pro-de-Guilherme.local, resolves to a loopback address: 127.0.0.1; using 192.168.15.135 instead (on interface en0)
# 25/12/03 13:05:12 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 25/12/03 13:05:12 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
RAW = "/Volumes/external/Dados/dataset_2/raw"
BRONZE = "/Volumes/external/Dados/dataset_2/bronze"
